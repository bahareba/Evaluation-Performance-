# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
df1_OP = pd.read_excel('data.xlsx', sheet_name="Order Products")
df1_vendors = pd.read_excel('data.xlsx', sheet_name="Vendors")
df1_orders = pd.read_excel('data.xlsx', sheet_name="Orders")
df1_raiting = pd.read_excel('data.xlsx', sheet_name="Ratings")

df1_orders.head()
# Out:
#    id               created_at  Customer ID Order Status      Cancel Reason  \
# 0   1  2021-01-01 04:04:18.000          101     Canceled  Customer Canceled
# 1   2  2021-01-01 10:00:10.000          102   Successful                NaN
# 2   3  2021-01-01 10:30:09.000          103   Successful                NaN
# 3   4  2021-01-01 11:28:51.000          104   Successful                NaN
# 4   5  2021-01-01 11:31:24.000          105   Successful                NaN
#
#     Vendor  SuperTypeID  Sub-Total  Total Discount  Discount Vendor Share  \
# 0  Store 1           12     302400          8400.0                      0
# 1  Store 2           12     899760         19560.0                      0
# 2  Store 3           12     149400         24900.0                  37350
# 3  Store 4           12     214400             0.0                      0
# 4  Store 5           12    1159200         25200.0                      0
#
#    Voucher Value  product models  items
# 0            0.0               4      4
# 1            0.0               1      1
# 2        25000.0               1      1
# 3        25000.0               2      2
# 4            0.0               1      1

# %%
df1_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70531 entries, 0 to 70530
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     70531 non-null  int64
#  1   created_at             70531 non-null  object
#  2   Customer ID            70531 non-null  int64
#  3   Order Status           70531 non-null  object
#  4   Cancel Reason          3418 non-null   object
#  5   Vendor                 70531 non-null  object
#  6   SuperTypeID            70531 non-null  int64
#  7   Sub-Total              70531 non-null  int64
#  8   Total Discount         70531 non-null  float64
#  9   Discount Vendor Share  70531 non-null  int64
#  10  Voucher Value          70531 non-null  float64
#  11  product models         70531 non-null  int64
#  12  items                  70531 non-null  int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 7.0+ MB

# %%
df1_OP['created_at']= pd.to_datetime(df1_OP['created_at'])
df1_OP['order_date'] = df1_OP['created_at'].dt.date
dfp = df1_OP.drop(["created_at"],axis=1)
dfp.head()
# Out:
#    Order ID  Customer ID Vendor Name  SuperTypeID  product id  quantity  \
# 0         1          101    Store 21           12       10001         1
# 1         2          102    Store 21           12       10002         1
# 2         3          103    Store 21           12       10003         1
# 3         4          104    Store 27           12       10004         1
# 4         5          105    Store 62           12       10004         1
#
#      price  order_date
# 0  2350000  2021-02-03
# 1   104000  2021-05-03
# 2   216000  2021-03-16
# 3    66500  2021-03-13
# 4    66500  2021-03-22

# %%
df1_vendors['CreatedAt']= pd.to_datetime(df1_vendors['CreatedAt'])
df1_vendors['vendor_created'] = df1_vendors['CreatedAt'].dt.date
dfv = df1_vendors.drop(["CreatedAt"],axis=1)
dfv.head()
# Out:
#   Vendor Name vendor_created
# 0     Store 1     2020-11-17
# 1     Store 2     2020-11-24
# 2     Store 3     2020-05-28
# 3     Store 4     2020-12-23
# 4     Store 5     2020-05-30

# %%
df1_orders['created_at']= pd.to_datetime(df1_orders['created_at'])
df1_orders['order_date'] = df1_orders['created_at'].dt.date
dfo = df1_orders.drop(["created_at"],axis=1)
dfo.head()
# Out:
#    id  Customer ID Order Status      Cancel Reason   Vendor  SuperTypeID  \
# 0   1          101     Canceled  Customer Canceled  Store 1           12
# 1   2          102   Successful                NaN  Store 2           12
# 2   3          103   Successful                NaN  Store 3           12
# 3   4          104   Successful                NaN  Store 4           12
# 4   5          105   Successful                NaN  Store 5           12
#
#    Sub-Total  Total Discount  Discount Vendor Share  Voucher Value  \
# 0     302400          8400.0                      0            0.0
# 1     899760         19560.0                      0            0.0
# 2     149400         24900.0                  37350        25000.0
# 3     214400             0.0                      0        25000.0
# 4    1159200         25200.0                      0            0.0
#
#    product models  items  order_date
# 0               4      4  2021-01-01
# 1               1      1  2021-01-01
# 2               1      1  2021-01-01
# 3               2      2  2021-01-01
# 4               1      1  2021-01-01

# %%
df1_raiting['created_at']= pd.to_datetime(df1_raiting['created_at'])
df1_raiting['order_date'] = df1_raiting['created_at'].dt.date
dfr = df1_raiting.drop(["created_at"],axis=1)
dfr.head()
# Out:
#    Order ID    Vendor  Product Models  Rating  order_date
# 0         1   Store 2               1       5  2021-01-01
# 1         2   Store 6               1       5  2021-01-01
# 2         3   Store 6               1       4  2021-01-01
# 3         4  Store 10               2       5  2021-01-01
# 4         5  Store 14               4       5  2021-01-01

# %%
dfo.head()
# Out:
#    id  Customer ID Order Status      Cancel Reason   Vendor  SuperTypeID  \
# 0   1          101     Canceled  Customer Canceled  Store 1           12
# 1   2          102   Successful                NaN  Store 2           12
# 2   3          103   Successful                NaN  Store 3           12
# 3   4          104   Successful                NaN  Store 4           12
# 4   5          105   Successful                NaN  Store 5           12
#
#    Sub-Total  Total Discount  Discount Vendor Share  Voucher Value  \
# 0     302400          8400.0                      0            0.0
# 1     899760         19560.0                      0            0.0
# 2     149400         24900.0                  37350        25000.0
# 3     214400             0.0                      0        25000.0
# 4    1159200         25200.0                      0            0.0
#
#    product models  items  order_date
# 0               4      4  2021-01-01
# 1               1      1  2021-01-01
# 2               1      1  2021-01-01
# 3               2      2  2021-01-01
# 4               1      1  2021-01-01

# %%
print(dfo["order_date"].min())
print(dfo["order_date"].max())
# Out:
# 2021-01-01
# 2021-06-20

# %%
dfo['order_date'] = pd.to_datetime(dfo['order_date'], errors='coerce')
dfo['order_month'] =  dfo['order_date'].dt.month


dfo.head()
# Out:
#    id  Customer ID Order Status      Cancel Reason   Vendor  SuperTypeID  \
# 0   1          101     Canceled  Customer Canceled  Store 1           12
# 1   2          102   Successful                NaN  Store 2           12
# 2   3          103   Successful                NaN  Store 3           12
# 3   4          104   Successful                NaN  Store 4           12
# 4   5          105   Successful                NaN  Store 5           12
#
#    Sub-Total  Total Discount  Discount Vendor Share  Voucher Value  \
# 0     302400          8400.0                      0            0.0
# 1     899760         19560.0                      0            0.0
# 2     149400         24900.0                  37350        25000.0
# 3     214400             0.0                      0        25000.0
# 4    1159200         25200.0                      0            0.0
#
#    product models  items order_date  order_month
# 0               4      4 2021-01-01            1
# 1               1      1 2021-01-01            1
# 2               1      1 2021-01-01            1
# 3               2      2 2021-01-01            1
# 4               1      1 2021-01-01            1

# %%
dfo.loc[dfo.order_month < 4 , 'which month'] = "month 1 - 3"
dfo.loc[dfo.order_month >= 4 , 'which month'] = "month 4 - 6"

dfo.head()
# Out:
#    id  Customer ID Order Status      Cancel Reason   Vendor  SuperTypeID  \
# 0   1          101     Canceled  Customer Canceled  Store 1           12
# 1   2          102   Successful                NaN  Store 2           12
# 2   3          103   Successful                NaN  Store 3           12
# 3   4          104   Successful                NaN  Store 4           12
# 4   5          105   Successful                NaN  Store 5           12
#
#    Sub-Total  Total Discount  Discount Vendor Share  Voucher Value  \
# 0     302400          8400.0                      0            0.0
# 1     899760         19560.0                      0            0.0
# 2     149400         24900.0                  37350        25000.0
# 3     214400             0.0                      0        25000.0
# 4    1159200         25200.0                      0            0.0
#
#    product models  items order_date  order_month  which month
# 0               4      4 2021-01-01            1  month 1 - 3
# 1               1      1 2021-01-01            1  month 1 - 3
# 2               1      1 2021-01-01            1  month 1 - 3
# 3               2      2 2021-01-01            1  month 1 - 3
# 4               1      1 2021-01-01            1  month 1 - 3

# %%
dfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70531 entries, 0 to 70530
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     70531 non-null  int64
#  1   Customer ID            70531 non-null  int64
#  2   Order Status           70531 non-null  object
#  3   Cancel Reason          3418 non-null   object
#  4   Vendor                 70531 non-null  object
#  5   SuperTypeID            70531 non-null  int64
#  6   Sub-Total              70531 non-null  int64
#  7   Total Discount         70531 non-null  float64
#  8   Discount Vendor Share  70531 non-null  int64
#  9   Voucher Value          70531 non-null  float64
#  10  product models         70531 non-null  int64
#  11  items                  70531 non-null  int64
#  12  order_date             70531 non-null  datetime64[ns]
#  13  order_month            70531 non-null  int64
#  14  which month            70531 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(8), object(4)
# memory usage: 8.1+ MB

# %%
dfo1 = dfo.groupby(["Vendor","which month","Order Status","SuperTypeID"]).agg({'id':'count', 'Customer ID' :'nunique','Sub-Total':'sum','Total Discount':'sum','Discount Vendor Share':'sum','Voucher Value':'sum','product models':'sum','items':'sum'}).reset_index()

dfo1.rename(columns={'Vendor': 'Vendor Name',
                         'id': 'orders',
                         'Customer ID': 'nunique_customers'}, inplace=True)
dfo1
# Out:
#      Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0        Store 1  month 1 - 3     Canceled           12      45
# 1        Store 1  month 1 - 3   Successful           12     478
# 2        Store 1  month 4 - 6     Canceled           12      13
# 3        Store 1  month 4 - 6   Successful           12     273
# 4       Store 10  month 1 - 3     Canceled           12     132
# ...          ...          ...          ...          ...     ...
# 1018    Store 98  month 4 - 6     Canceled           13       2
# 1019    Store 98  month 4 - 6   Successful           13      25
# 1020    Store 99  month 1 - 3     Canceled           12       2
# 1021    Store 99  month 1 - 3   Successful           12       6
# 1022    Store 99  month 4 - 6     Canceled           12       2
#
#       nunique_customers  Sub-Total  Total Discount  Discount Vendor Share  \
# 0                    44   11588174        321821.5                  15000
# 1                   444  111299086       3232618.5                 408815
# 2                    13    3073348        109093.0                  80850
# 3                   260   61332142       1531649.5                1269700
# 4                   125   35788678        432701.0                 865402
# ...                 ...        ...             ...                    ...
# 1018                  2     657400         28150.0                  17800
# 1019                 24    4914120        340170.0                 334400
# 1020                  2       4000             0.0                      0
# 1021                  1      12000             0.0                      0
# 1022                  1       4000             0.0                      0
#
#       Voucher Value  product models  items
# 0              0.00              97    122
# 1        5558754.00            1324   1559
# 2              0.00              26     57
# 3        1655000.00             847   1005
# 4              0.00             380    458
# ...             ...             ...    ...
# 1018           0.00               7      7
# 1019      138263.75             150    159
# 1020           0.00               2      2
# 1021           0.00               6      6
# 1022           0.00               2      2
#
# [1023 rows x 12 columns]

# %%
data = pd.merge(dfo1, dfv, how='outer', on=['Vendor Name'])
data.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers  Sub-Total  Total Discount  Discount Vendor Share  \
# 0                 44   11588174        321821.5                  15000
# 1                444  111299086       3232618.5                 408815
# 2                 13    3073348        109093.0                  80850
# 3                260   61332142       1531649.5                1269700
# 4                125   35788678        432701.0                 865402
#
#    Voucher Value  product models  items vendor_created
# 0            0.0              97    122     2020-11-17
# 1      5558754.0            1324   1559     2020-11-17
# 2            0.0              26     57     2020-11-17
# 3      1655000.0             847   1005     2020-11-17
# 4            0.0             380    458     2020-04-15

# %%
print(data["vendor_created"].min())
print(data["vendor_created"].max())
# Out:
# 2020-04-13
# 2021-06-02

# %%
dfo.head()
# Out:
#    id  Customer ID Order Status      Cancel Reason   Vendor  SuperTypeID  \
# 0   1          101     Canceled  Customer Canceled  Store 1           12
# 1   2          102   Successful                NaN  Store 2           12
# 2   3          103   Successful                NaN  Store 3           12
# 3   4          104   Successful                NaN  Store 4           12
# 4   5          105   Successful                NaN  Store 5           12
#
#    Sub-Total  Total Discount  Discount Vendor Share  Voucher Value  \
# 0     302400          8400.0                      0            0.0
# 1     899760         19560.0                      0            0.0
# 2     149400         24900.0                  37350        25000.0
# 3     214400             0.0                      0        25000.0
# 4    1159200         25200.0                      0            0.0
#
#    product models  items order_date  order_month  which month
# 0               4      4 2021-01-01            1  month 1 - 3
# 1               1      1 2021-01-01            1  month 1 - 3
# 2               1      1 2021-01-01            1  month 1 - 3
# 3               2      2 2021-01-01            1  month 1 - 3
# 4               1      1 2021-01-01            1  month 1 - 3

# %%
dfo['order_date'] = pd.to_datetime(dfo['order_date'], errors='coerce')
dfo['order_week'] =  dfo['order_date'].dt.week


dfo.head()
# Out:
# <ipython-input-17-dd8040f9b775>:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   dfo['order_week'] =  dfo['order_date'].dt.week
#    id  Customer ID Order Status      Cancel Reason   Vendor  SuperTypeID  \
# 0   1          101     Canceled  Customer Canceled  Store 1           12
# 1   2          102   Successful                NaN  Store 2           12
# 2   3          103   Successful                NaN  Store 3           12
# 3   4          104   Successful                NaN  Store 4           12
# 4   5          105   Successful                NaN  Store 5           12
#
#    Sub-Total  Total Discount  Discount Vendor Share  Voucher Value  \
# 0     302400          8400.0                      0            0.0
# 1     899760         19560.0                      0            0.0
# 2     149400         24900.0                  37350        25000.0
# 3     214400             0.0                      0        25000.0
# 4    1159200         25200.0                      0            0.0
#
#    product models  items order_date  order_month  which month  order_week
# 0               4      4 2021-01-01            1  month 1 - 3          53
# 1               1      1 2021-01-01            1  month 1 - 3          53
# 2               1      1 2021-01-01            1  month 1 - 3          53
# 3               2      2 2021-01-01            1  month 1 - 3          53
# 4               1      1 2021-01-01            1  month 1 - 3          53

# %%
df_test = dfo.groupby(["Vendor","order_week"]).agg({'order_date':'nunique'}).reset_index()
df_test
# Out:
#         Vendor  order_week  order_date
# 0      Store 1           1           6
# 1      Store 1           2           5
# 2      Store 1           3           6
# 3      Store 1           4           5
# 4      Store 1           5           6
# ...        ...         ...         ...
# 3413  Store 99           7           1
# 3414  Store 99           8           1
# 3415  Store 99           9           1
# 3416  Store 99          10           1
# 3417  Store 99          17           2
#
# [3418 rows x 3 columns]

# %%
df_test2 = df_test.groupby(["Vendor"]).agg({'order_date':'mean'}).round().reset_index()
df_test2
# Out:
#         Vendor  order_date
# 0      Store 1         5.0
# 1     Store 10         6.0
# 2    Store 100         4.0
# 3    Store 101         6.0
# 4    Store 102         1.0
# ..         ...         ...
# 434   Store 95         2.0
# 435   Store 96         2.0
# 436   Store 97         1.0
# 437   Store 98         2.0
# 438   Store 99         1.0
#
# [439 rows x 2 columns]

# %%
df_test2.rename(columns={'order_date': 'ave_active_per_week','Vendor':'Vendor Name'}, inplace=True)
df_test2.head()
# Out:
#   Vendor Name  ave_active_per_week
# 0     Store 1                  5.0
# 1    Store 10                  6.0
# 2   Store 100                  4.0
# 3   Store 101                  6.0
# 4   Store 102                  1.0

# %%
data1 = pd.merge(data, df_test2, how='outer', on=['Vendor Name'])
data1.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers  Sub-Total  Total Discount  Discount Vendor Share  \
# 0                 44   11588174        321821.5                  15000
# 1                444  111299086       3232618.5                 408815
# 2                 13    3073348        109093.0                  80850
# 3                260   61332142       1531649.5                1269700
# 4                125   35788678        432701.0                 865402
#
#    Voucher Value  product models  items vendor_created  ave_active_per_week
# 0            0.0              97    122     2020-11-17                  5.0
# 1      5558754.0            1324   1559     2020-11-17                  5.0
# 2            0.0              26     57     2020-11-17                  5.0
# 3      1655000.0             847   1005     2020-11-17                  5.0
# 4            0.0             380    458     2020-04-15                  6.0

# %%
data1["basket_value"] = (data1["Sub-Total"] / data1["orders"]).round()
data1["ave_discount_t"] = (data1["Total Discount"] / data1["orders"]).round()
data1["ave_discount_v"] = (data1["Discount Vendor Share"] / data1["orders"]).round()


data1["ave_voucher"] = (data1["Voucher Value"] / data1["orders"]).round()
data1["ave_model"] = (data1["product models"] / data1["orders"]).round()
data1["ave_items"] = (data1["items"] / data1["orders"]).round()

data2 = data1.drop(["Sub-Total","Total Discount","Discount Vendor Share","Voucher Value","product models","items"],axis=1)
data2.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers vendor_created  ave_active_per_week  basket_value  \
# 0                 44     2020-11-17                  5.0      257515.0
# 1                444     2020-11-17                  5.0      232843.0
# 2                 13     2020-11-17                  5.0      236411.0
# 3                260     2020-11-17                  5.0      224660.0
# 4                125     2020-04-15                  6.0      271126.0
#
#    ave_discount_t  ave_discount_v  ave_voucher  ave_model  ave_items
# 0          7152.0           333.0          0.0        2.0        3.0
# 1          6763.0           855.0      11629.0        3.0        3.0
# 2          8392.0          6219.0          0.0        2.0        4.0
# 3          5610.0          4651.0       6062.0        3.0        4.0
# 4          3278.0          6556.0          0.0        3.0        3.0

# %%
data2[data2["which month"] == "month 1 - 3"]["orders"].sum()
# Out:
# 32086

# %%
data2.loc[data2["which month"] == "month 1 - 3" , 'all order'] = 32068
data2.loc[data2["which month"] != "month 1 - 3" , 'all order'] = 38445

data2.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers vendor_created  ave_active_per_week  basket_value  \
# 0                 44     2020-11-17                  5.0      257515.0
# 1                444     2020-11-17                  5.0      232843.0
# 2                 13     2020-11-17                  5.0      236411.0
# 3                260     2020-11-17                  5.0      224660.0
# 4                125     2020-04-15                  6.0      271126.0
#
#    ave_discount_t  ave_discount_v  ave_voucher  ave_model  ave_items  \
# 0          7152.0           333.0          0.0        2.0        3.0
# 1          6763.0           855.0      11629.0        3.0        3.0
# 2          8392.0          6219.0          0.0        2.0        4.0
# 3          5610.0          4651.0       6062.0        3.0        4.0
# 4          3278.0          6556.0          0.0        3.0        3.0
#
#    all order
# 0    32068.0
# 1    32068.0
# 2    38445.0
# 3    38445.0
# 4    32068.0

# %%
df_test3 = data2.groupby(["Vendor Name","which month"]).agg({'orders':'sum'}).reset_index()

df_test3.loc[df_test3["which month"] == "month 1 - 3" , 'all order'] = 32068
df_test3.loc[df_test3["which month"] != "month 1 - 3" , 'all order'] = 38445

df_test3["sales_share"] = ((df_test3["orders"] / df_test3["all order"])*100).round()

df_test4 = df_test3.drop(["orders","all order"],axis=1)
df_test4.head()
# Out:
#   Vendor Name  which month  sales_share
# 0     Store 1  month 1 - 3          2.0
# 1     Store 1  month 4 - 6          1.0
# 2    Store 10  month 1 - 3          2.0
# 3    Store 10  month 4 - 6          2.0
# 4   Store 100  month 1 - 3          1.0

# %%
data2.shape
# Out:
# (1023, 15)

# %%
data3 = pd.merge(data2, df_test4, how='outer', on=['Vendor Name','which month'])
data4 = data3.drop(["all order"],axis=1)
data4.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers vendor_created  ave_active_per_week  basket_value  \
# 0                 44     2020-11-17                  5.0      257515.0
# 1                444     2020-11-17                  5.0      232843.0
# 2                 13     2020-11-17                  5.0      236411.0
# 3                260     2020-11-17                  5.0      224660.0
# 4                125     2020-04-15                  6.0      271126.0
#
#    ave_discount_t  ave_discount_v  ave_voucher  ave_model  ave_items  \
# 0          7152.0           333.0          0.0        2.0        3.0
# 1          6763.0           855.0      11629.0        3.0        3.0
# 2          8392.0          6219.0          0.0        2.0        4.0
# 3          5610.0          4651.0       6062.0        3.0        4.0
# 4          3278.0          6556.0          0.0        3.0        3.0
#
#    sales_share
# 0          2.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          2.0

# %%
dfp.head()
# Out:
#    Order ID  Customer ID Vendor Name  SuperTypeID  product id  quantity  \
# 0         1          101    Store 21           12       10001         1
# 1         2          102    Store 21           12       10002         1
# 2         3          103    Store 21           12       10003         1
# 3         4          104    Store 27           12       10004         1
# 4         5          105    Store 62           12       10004         1
#
#      price  order_date
# 0  2350000  2021-02-03
# 1   104000  2021-05-03
# 2   216000  2021-03-16
# 3    66500  2021-03-13
# 4    66500  2021-03-22

# %%
dfp1 = dfp.groupby(["Vendor Name"]).agg({'product id':'nunique'})
dfp1.rename(columns={'product id': 'product variety'}, inplace=True)
dfp1
# Out:
#              product variety
# Vendor Name
# Store 1                  777
# Store 10                1710
# Store 100                254
# Store 101                157
# Store 102                 45
# ...                      ...
# Store 95                   4
# Store 96                  70
# Store 97                   6
# Store 98                 173
# Store 99                   1
#
# [398 rows x 1 columns]

# %%
data5 = pd.merge(data4, dfp1, how='outer', on=['Vendor Name'])
data5.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers vendor_created  ave_active_per_week  basket_value  \
# 0                 44     2020-11-17                  5.0      257515.0
# 1                444     2020-11-17                  5.0      232843.0
# 2                 13     2020-11-17                  5.0      236411.0
# 3                260     2020-11-17                  5.0      224660.0
# 4                125     2020-04-15                  6.0      271126.0
#
#    ave_discount_t  ave_discount_v  ave_voucher  ave_model  ave_items  \
# 0          7152.0           333.0          0.0        2.0        3.0
# 1          6763.0           855.0      11629.0        3.0        3.0
# 2          8392.0          6219.0          0.0        2.0        4.0
# 3          5610.0          4651.0       6062.0        3.0        4.0
# 4          3278.0          6556.0          0.0        3.0        3.0
#
#    sales_share  product variety
# 0          2.0            777.0
# 1          2.0            777.0
# 2          1.0            777.0
# 3          1.0            777.0
# 4          2.0           1710.0

# %%
dfr.head()
# Out:
#    Order ID    Vendor  Product Models  Rating  order_date
# 0         1   Store 2               1       5  2021-01-01
# 1         2   Store 6               1       5  2021-01-01
# 2         3   Store 6               1       4  2021-01-01
# 3         4  Store 10               2       5  2021-01-01
# 4         5  Store 14               4       5  2021-01-01

# %%
dfr1 = dfr.groupby(["Vendor"]).agg({'Rating':'mean'}).round().reset_index()

dfr1.rename(columns={'Vendor': 'Vendor Name'}, inplace=True)

dfr1
# Out:
#     Vendor Name  Rating
# 0       Store 1     4.0
# 1      Store 10     4.0
# 2     Store 100     4.0
# 3     Store 101     5.0
# 4     Store 102     5.0
# ..          ...     ...
# 276    Store 95     5.0
# 277    Store 96     4.0
# 278    Store 97     4.0
# 279    Store 98     5.0
# 280    Store 99     4.0
#
# [281 rows x 2 columns]

# %%
data6 = pd.merge(data5, dfr1, how='outer', on=['Vendor Name'])
data6.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers vendor_created  ave_active_per_week  basket_value  \
# 0                 44     2020-11-17                  5.0      257515.0
# 1                444     2020-11-17                  5.0      232843.0
# 2                 13     2020-11-17                  5.0      236411.0
# 3                260     2020-11-17                  5.0      224660.0
# 4                125     2020-04-15                  6.0      271126.0
#
#    ave_discount_t  ave_discount_v  ave_voucher  ave_model  ave_items  \
# 0          7152.0           333.0          0.0        2.0        3.0
# 1          6763.0           855.0      11629.0        3.0        3.0
# 2          8392.0          6219.0          0.0        2.0        4.0
# 3          5610.0          4651.0       6062.0        3.0        4.0
# 4          3278.0          6556.0          0.0        3.0        3.0
#
#    sales_share  product variety  Rating
# 0          2.0            777.0     4.0
# 1          2.0            777.0     4.0
# 2          1.0            777.0     4.0
# 3          1.0            777.0     4.0
# 4          2.0           1710.0     4.0

# %%
#data6.to_excel(r'C:\Users\bahare\Desktop\snappshop\final.xlsx', index = True, header=True)

# %%
data7 = data6.groupby(["Vendor Name","which month"]).agg({'orders':'sum'}).reset_index()
data7.rename(columns={'orders': 'all order'}, inplace=True)

data7
# Out:
#     Vendor Name  which month  all order
# 0       Store 1  month 1 - 3        523
# 1       Store 1  month 4 - 6        286
# 2      Store 10  month 1 - 3        782
# 3      Store 10  month 4 - 6        839
# 4     Store 100  month 1 - 3        196
# ..          ...          ...        ...
# 612    Store 97  month 4 - 6          1
# 613    Store 98  month 1 - 3         17
# 614    Store 98  month 4 - 6         27
# 615    Store 99  month 1 - 3          8
# 616    Store 99  month 4 - 6          2
#
# [617 rows x 3 columns]

# %%
data9 = pd.merge(data6,data7, how='outer', on=['Vendor Name','which month'])
data9.head()
# Out:
#   Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0     Store 1  month 1 - 3     Canceled           12      45
# 1     Store 1  month 1 - 3   Successful           12     478
# 2     Store 1  month 4 - 6     Canceled           12      13
# 3     Store 1  month 4 - 6   Successful           12     273
# 4    Store 10  month 1 - 3     Canceled           12     132
#
#    nunique_customers vendor_created  ave_active_per_week  basket_value  \
# 0                 44     2020-11-17                  5.0      257515.0
# 1                444     2020-11-17                  5.0      232843.0
# 2                 13     2020-11-17                  5.0      236411.0
# 3                260     2020-11-17                  5.0      224660.0
# 4                125     2020-04-15                  6.0      271126.0
#
#    ave_discount_t  ave_discount_v  ave_voucher  ave_model  ave_items  \
# 0          7152.0           333.0          0.0        2.0        3.0
# 1          6763.0           855.0      11629.0        3.0        3.0
# 2          8392.0          6219.0          0.0        2.0        4.0
# 3          5610.0          4651.0       6062.0        3.0        4.0
# 4          3278.0          6556.0          0.0        3.0        3.0
#
#    sales_share  product variety  Rating  all order
# 0          2.0            777.0     4.0        523
# 1          2.0            777.0     4.0        523
# 2          1.0            777.0     4.0        286
# 3          1.0            777.0     4.0        286
# 4          2.0           1710.0     4.0        782

# %%
data9["rate"] = ((data9["orders"] / data9["all order"])*100).round()
data9
# Out:
#      Vendor Name  which month Order Status  SuperTypeID  orders  \
# 0        Store 1  month 1 - 3     Canceled           12      45
# 1        Store 1  month 1 - 3   Successful           12     478
# 2        Store 1  month 4 - 6     Canceled           12      13
# 3        Store 1  month 4 - 6   Successful           12     273
# 4       Store 10  month 1 - 3     Canceled           12     132
# ...          ...          ...          ...          ...     ...
# 1018    Store 98  month 4 - 6     Canceled           13       2
# 1019    Store 98  month 4 - 6   Successful           13      25
# 1020    Store 99  month 1 - 3     Canceled           12       2
# 1021    Store 99  month 1 - 3   Successful           12       6
# 1022    Store 99  month 4 - 6     Canceled           12       2
#
#       nunique_customers vendor_created  ave_active_per_week  basket_value  \
# 0                    44     2020-11-17                  5.0      257515.0
# 1                   444     2020-11-17                  5.0      232843.0
# 2                    13     2020-11-17                  5.0      236411.0
# 3                   260     2020-11-17                  5.0      224660.0
# 4                   125     2020-04-15                  6.0      271126.0
# ...                 ...            ...                  ...           ...
# 1018                  2     2020-12-22                  2.0      328700.0
# 1019                 24     2020-12-22                  2.0      196565.0
# 1020                  2     2020-10-10                  1.0        2000.0
# 1021                  1     2020-10-10                  1.0        2000.0
# 1022                  1     2020-10-10                  1.0        2000.0
#
#       ave_discount_t  ave_discount_v  ave_voucher  ave_model  ave_items  \
# 0             7152.0           333.0          0.0        2.0        3.0
# 1             6763.0           855.0      11629.0        3.0        3.0
# 2             8392.0          6219.0          0.0        2.0        4.0
# 3             5610.0          4651.0       6062.0        3.0        4.0
# 4             3278.0          6556.0          0.0        3.0        3.0
# ...              ...             ...          ...        ...        ...
# 1018         14075.0          8900.0          0.0        4.0        4.0
# 1019         13607.0         13376.0       5531.0        6.0        6.0
# 1020             0.0             0.0          0.0        1.0        1.0
# 1021             0.0             0.0          0.0        1.0        1.0
# 1022             0.0             0.0          0.0        1.0        1.0
#
#       sales_share  product variety  Rating  all order   rate
# 0             2.0            777.0     4.0        523    9.0
# 1             2.0            777.0     4.0        523   91.0
# 2             1.0            777.0     4.0        286    5.0
# 3             1.0            777.0     4.0        286   95.0
# 4             2.0           1710.0     4.0        782   17.0
# ...           ...              ...     ...        ...    ...
# 1018          0.0            173.0     5.0         27    7.0
# 1019          0.0            173.0     5.0         27   93.0
# 1020          0.0              1.0     4.0          8   25.0
# 1021          0.0              1.0     4.0          8   75.0
# 1022          0.0              1.0     4.0          2  100.0
#
# [1023 rows x 19 columns]

# %% [markdown]
# # Scoring

# %%
data10 = data6.groupby(["Vendor Name"]).agg({'orders':'sum'}).reset_index()
data10.rename(columns={'orders': 'all order'}, inplace=True)

data10
# Out:
#     Vendor Name  all order
# 0       Store 1        809
# 1      Store 10       1621
# 2     Store 100        274
# 3     Store 101       1459
# 4     Store 102         19
# ..          ...        ...
# 434    Store 95         16
# 435    Store 96         82
# 436    Store 97          6
# 437    Store 98         44
# 438    Store 99         10
#
# [439 rows x 2 columns]

# %%
data10["all order"].hist()
# Out:
# <AxesSubplot:>

# %%
print(data10["all order"].min())
print("10th percentile of arr : ",
       np.percentile(data10["all order"], 10))
print("20th percentile of arr : ",
       np.percentile(data10["all order"], 20))
print("30th percentile of arr : ",
       np.percentile(data10["all order"], 30))
print("40th percentile of arr : ", 
       np.percentile(data10["all order"], 40))
print("50th percentile of arr : ",
       np.percentile(data10["all order"], 50))
print("60th percentile of arr : ",
       np.percentile(data10["all order"], 60))
print("70th percentile of arr : ",
       np.percentile(data10["all order"], 70))
print("80th percentile of arr : ", 
       np.percentile(data10["all order"], 80))
print("90th percentile of arr : ",
       np.percentile(data10["all order"], 90))
print("10th percentile of arr : ",
       np.percentile(data10["all order"], 100))
# Out:
# 1
# 10th percentile of arr :  1.0
# 20th percentile of arr :  3.0
# 30th percentile of arr :  5.0
# 40th percentile of arr :  8.0
# 50th percentile of arr :  13.0
# 60th percentile of arr :  23.0
# 70th percentile of arr :  43.599999999999966
# 80th percentile of arr :  106.60000000000014
# 90th percentile of arr :  368.99999999999983
# 10th percentile of arr :  7143.0

# %%
data10.head()
# Out:
#   Vendor Name  all order  score_NumberOrder
# 0          20         20               20.0
# 1          20         20               20.0
# 2          20         20               20.0
# 3          20         20               20.0
# 4          10         10               10.0

# %%
data10.loc[data10["all order"] <= 10, 'score_NumberOrder'] = 5
data10.loc[(data10["all order"] > 10) & (data10["all order"] <= 30)] = 10
data10.loc[(data10["all order"] >30) & (data10["all order"] <= 50)] = 15
data10.loc[data10["all order"] > 50] = 20
data10.head(15)
# Out:
#    Vendor Name  all order  score_NumberOrder
# 0           20         20               20.0
# 1           20         20               20.0
# 2           20         20               20.0
# 3           20         20               20.0
# 4           10         10               10.0
# 5           10         10               10.0
# 6           20         20               20.0
# 7           10         10               10.0
# 8           10         10               10.0
# 9           10         10               10.0
# 10          10         10               10.0
# 11          20         20               20.0
# 12          20         20               20.0
# 13   Store 110          3                5.0
# 14          10         10               10.0
